# %%
import pandas as pd
from pandas import json_normalize
import numpy as np
import json as js
import ast as ast
import re
import json

# %%
#Convertir el archivo 'australian_user_reviews.json' en dataframe

list_rev = []
usuarios_reviews = r'australian_user_reviews.json'
with open(usuarios_reviews, encoding='utf-8') as file:
    for line in file.readlines():
        list_rev.append(ast.literal_eval(line))

DF_Reviews = pd.DataFrame(list_rev)
DF_Reviews = DF_Reviews.explode('reviews',  ignore_index=True)

# %%
Reviews2 = pd.DataFrame(list_rev)
Reviews = Reviews2.explode('reviews', ignore_index=True)
Reviews
# Out:
#                  user_id                                           user_url  \
# 0      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 2      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 3                js41637               http://steamcommunity.com/id/js41637
# 4                js41637               http://steamcommunity.com/id/js41637
# ...                  ...                                                ...
# 59328  76561198312638244  http://steamcommunity.com/profiles/76561198312...
# 59329  76561198312638244  http://steamcommunity.com/profiles/76561198312...
# 59330        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
# 59331        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
# 59332        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
#
#                                                  reviews
# ...

# %%
Reviews_expanded = pd.json_normalize(Reviews['reviews'])
Reviews_expanded
# Out:
#                                   funny                     posted  \
# 0                                         Posted November 5, 2011.
# 1                                            Posted July 15, 2011.
# 2                                           Posted April 21, 2011.
# 3                                            Posted June 24, 2014.
# 4                                        Posted September 8, 2013.
# ...                                 ...                        ...
# 59328                                              Posted July 10.
# 59329                                               Posted July 8.
# 59330  1 person found this review funny             Posted July 3.
# 59331                                              Posted July 20.
# 59332                                               Posted July 2.
#
#       last_edited item_id                                          helpful  \
# 0                    1250                                   No ratings yet
# ...

# %%
Reviews_expanded=Reviews_expanded.replace('',None)
Reviews_expanded
# Out:
#                                   funny                     posted  \
# 0                                  None   Posted November 5, 2011.
# 1                                  None      Posted July 15, 2011.
# 2                                  None     Posted April 21, 2011.
# 3                                  None      Posted June 24, 2014.
# 4                                  None  Posted September 8, 2013.
# ...                                 ...                        ...
# 59328                              None            Posted July 10.
# 59329                              None             Posted July 8.
# 59330  1 person found this review funny             Posted July 3.
# 59331                              None            Posted July 20.
# 59332                              None             Posted July 2.
#
#       last_edited item_id                                          helpful  \
# 0            None    1250                                   No ratings yet
# ...

# %%
Reviews = Reviews.join(Reviews_expanded)
Reviews
# Out:
#                  user_id                                           user_url  \
# 0      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 2      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 3                js41637               http://steamcommunity.com/id/js41637
# 4                js41637               http://steamcommunity.com/id/js41637
# ...                  ...                                                ...
# 59328  76561198312638244  http://steamcommunity.com/profiles/76561198312...
# 59329  76561198312638244  http://steamcommunity.com/profiles/76561198312...
# 59330        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
# 59331        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
# 59332        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
#
# ...

# %%
Reviews.drop(columns=['reviews','last_edited','user_url'],inplace=True)
Reviews
# Out:
#                  user_id                             funny  \
# 0      76561197970982479                              None
# 1      76561197970982479                              None
# 2      76561197970982479                              None
# 3                js41637                              None
# 4                js41637                              None
# ...                  ...                               ...
# 59328  76561198312638244                              None
# 59329  76561198312638244                              None
# 59330        LydiaMorley  1 person found this review funny
# 59331        LydiaMorley                              None
# 59332        LydiaMorley                              None
#
#                           posted item_id  \
# 0       Posted November 5, 2011.    1250
# 1          Posted July 15, 2011.   22200
# 2         Posted April 21, 2011.   43110
# 3          Posted June 24, 2014.  251610
# 4      Posted September 8, 2013.  227300
# ...
